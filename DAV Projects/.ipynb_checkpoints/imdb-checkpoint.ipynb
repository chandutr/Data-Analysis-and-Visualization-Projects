# %%
import pandas as pd
df=pd.read_csv(r"imdb_data.csv")
df.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
df.shape
# Out:
# (3000, 23)

# %%
df[0:10]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# ...

# %% [markdown]
# iloc(only int argument, use index values) and loc func is used to slicing rows and columns

# %%
df.iloc[0:3]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
# ...

# %% [markdown]
# df.iloc first agurment for row slicing and 2nd argument for column slicing

# %%
df.iloc[0:5,1:3]
# Out:
#                                belongs_to_collection    budget
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0

# %%
df.iloc[:,-3:]
# Out:
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# ...

# %%
df.iloc[150:176,-5:-2]
# Out:
#                                         title  \
# 150                                Windwalker
# 151                                 Holy Hell
# 152                                Paperhouse
# 153                         The Boy Next Door
# 154                                 Vigilante
# 155                      Return to Never Land
# 156                              Shadowboxing
# 157            American Cyborg: Steel Warrior
# 158                                Get Carter
# 159                    The Quick and the Dead
# 160                            Winter Passing
# 161                               Casual Sex?
# 162                      Your Sister's Sister
# 163                                  Rushmore
# 164                               The Reaping
# 165                        Ghosts Can't Do It
# 166                             Koyaanisqatsi
# 167                The Exorcism of Emily Rose
# 168            The Return of the Pink Panther
# ...

# %%
df.iloc[-5:,:10]
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %%
df.iloc[-10:-1,-5:]
# Out:
#                         title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
#
#                                                Keywords  \
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
#
#                                                    cast  \
# ...

# %%
df.iloc[195:-4,0:]
# Out:
#         id                              belongs_to_collection    budget  \
# 195    196                                                NaN         0
# 196    197                                                NaN   7000000
# 197    198                                                NaN  60000000
# 198    199                                                NaN  24000000
# 199    200                                                NaN  12600000
# ...    ...                                                ...       ...
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
#
#                                                  genres  \
# ...

# %%
df.iloc[:-150, 7:]
# Out:
#                                          original_title  \
# 0                                Hot Tub Time Machine 2
# 1              The Princess Diaries 2: Royal Engagement
# 2                                              Whiplash
# 3                                               Kahaani
# 4                                                  마린보이
# ...                                                 ...
# 2845  Who Is Harry Nilsson (And Why Is Everybody Tal...
# 2846                                             Robots
# 2847                                                '71
# 2848                                        Jersey Boys
# 2849                                            Стиляги
#
#                                                overview  popularity  \
# 0     When Lou, who has become the "father of the In...    6.575393
# 1     Mia Thermopolis is now a college graduate and ...    8.248895
# 2     Under the direction of a ruthless instructor, ...   64.299990
# ...

# %% [markdown]
# df.loc[1:3,[' ',' ']] 1:3--> row index [' ',' ']--> column names

# %%
df.loc[1:3,['genres','imdb_id']]
# Out:
#                                               genres    imdb_id
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480

# %%
df.loc[50:60,['budget','runtime','cast']]
# Out:
#        budget  runtime                                               cast
# 50     560000    102.0  [{'cast_id': 3, 'character': 'Matty', 'credit_...
# 51   12000000    160.0  [{'cast_id': 1, 'character': 'Prof. Fate', 'cr...
# 52          0     97.0  [{'cast_id': 6, 'character': 'Noah Dugan', 'cr...
# 53          0     98.0  [{'cast_id': 4, 'character': 'Darcy Elliot Bob...
# 54   20000000    107.0  [{'cast_id': 0, 'character': 'Lucius', 'credit...
# 55          0     95.0  [{'cast_id': 1, 'character': 'Crawl', 'credit_...
# 56          0     97.0  [{'cast_id': 1, 'character': 'H√©l√®ne', 'cred...
# 57  125000000    125.0  [{'cast_id': 4, 'character': 'Bruce Wayne / Ba...
# 58          0     95.0  [{'cast_id': 1, 'character': 'Timothy', 'credi...
# 59   14000000     95.0  [{'cast_id': 1, 'character': 'Bucum', 'credit_...
# 60  150000000    144.0  [{'cast_id': 1, 'character': 'James Bond', 'cr...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
en_movies=df[df['original_language']=='en']
en_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# ...

# %%
other_movies=df[df['original_language']!='en']
other_movies.shape[0]
# Out:
# 425

# %%
runtime=df[df['runtime']>120]
runtime
# Out:
#         id                              belongs_to_collection     budget  \
# 3        4                                                NaN    1200000
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# ...    ...                                                ...        ...
# 2969  2970                                                NaN   19800000
# 2970  2971                                                NaN   25000000
# 2980  2981                                                NaN     300000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
#
#                                                  genres  \
# ...

# %%
long_movies=df[(df['runtime']>120) & (df['original_language']=='en')]
long_movies
# Out:
#         id                              belongs_to_collection     budget  \
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37      38                                                NaN   50000000
# ...    ...                                                ...        ...
# 2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...    2000000
# 2969  2970                                                NaN   19800000
# 2970  2971                                                NaN   25000000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
#
#                                                  genres  \
# ...

# %%
short_movies=df[(df['runtime']<=120) & (df['original_language']!='en')]
short_movies
# Out:
#         id belongs_to_collection    budget  \
# 4        5                   NaN         0
# 15      16                   NaN    500000
# 30      31                   NaN  13000000
# 31      32                   NaN         0
# 45      46                   NaN   3906840
# ...    ...                   ...       ...
# 2942  2943                   NaN  12000000
# 2949  2950                   NaN   3000000
# 2972  2973                   NaN         0
# 2988  2989                   NaN         0
# 2996  2997                   NaN         0
#
#                                                  genres  \
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 30    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 31    [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
# 45    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# ...                                                 ...
# ...

# %%
df.describe() #2e07-> gives 2.25*e+07=2.25*(10**7), describe gives info about numerical columns present in the dataset(count,mean,std,min,25%,50%,75% and max)
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
def uppercase(column):
    return column.upper()

# %%
df['capitalized_title']=df['original_title'].apply(uppercase)
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# capitalized_title         object
# dtype: object

# %%
df['release_date'].dtype
# Out:
# dtype('O')

# %%
df['release_date']=pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10000\3738879061.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['release_date']=pd.to_datetime(df['release_date'])
# id                                int64
# belongs_to_collection            object
# budget                            int64
# genres                           object
# homepage                         object
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                      float64
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# runtime                         float64
# spoken_languages                 object
# ...

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df['Month']=df['release_date'].dt.month

# %%
df[['release_date','Month']].head()
# Out:
#   release_date  Month
# 0   2015-02-20      2
# 1   2004-08-06      8
# 2   2014-10-10     10
# 3   2012-03-09      3
# 4   2009-02-05      2

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df['Year']=df['release_date'].dt.year

# %%
df['Day']=df['release_date'].dt.day

# %%
df[['release_date','Month','Year','Day']].head()
# Out:
#   release_date  Month  Year  Day
# 0   2015-02-20      2  2015   20
# 1   2004-08-06      8  2004    6
# 2   2014-10-10     10  2014   10
# 3   2012-03-09      3  2012    9
# 4   2009-02-05      2  2009    5
