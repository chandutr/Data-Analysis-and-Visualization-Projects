# %% [markdown]
# <a href="https://colab.research.google.com/github/chandutr/Data-Analysis-and-Visualization-Projects/blob/main/ML_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Refer SCalon website for ML
#
#
# What is Machine Learning?
#
# *Machine Learning is an application of artificial intelligence that involves algorithms and data that automatically analyse and make decision by itself without human interaction
#
# *It describes how computer performs tasks on their own by previous experience
#
# ADVANTAGES
#
# 1) fast, accurate, efficient
#
# 2)automation of most applications
#
# 3)wide range of real life applications
#
# 4)enhanced cyber security and spam detection
#
# 5)no human intervention is needed
#
# 6)handling multi dimensional data
#
# DISADVANTAGE
#
# 1)it is very difficult to identify and rectify the errors
#
# 2)data acquisition--->data collection
#
# 3)interpretation of results required more time and space![Screenshot (144).png](data:image/png;base64,...)

# %% [markdown]
# Supervised Learning
#
# * Supervised learning is the types of ML in which machines are trained using  well "labelled" training data, and on basis of that data , machines predict the output.
#
# * The labelled data means some input data ia already tagged with the correct output.
#
# * Examples:
# 1. house price prediction
# 2. image calssification
# 3. Fraud detection
# 4. Spam filtering
#
# Categories of Supervised ML
#
# 1. Regression
# - The output is continuous or contiguous
# - Ex: house price prediction,stock market prediction,weather prediction etc
#
# 2. Classification
# - It is process of predicting from a group of predefined number of categories
# - Ex: spam prediction,sentimental analysis,churn prediction

# %% [markdown]
# Unsupervised Learning
#
# * It's a ML technique in  which the users donot need to supervise  the model
# * Instead it allows the model to work on its own to discover the patterns and information that was previously undetected
# * it mainly deals with the un labelled data
# * It includes clustering,associations and neural networks etc

# %% [markdown]
# Encoding
#
# It is a process by which categorical variables are converted into a form that could be provided to ML algorithms to do a better job in prediction.
#
# 1. One Hot Encoding
# * One hot encoding creates new(binary/boolean) columns , indicating the presence of each possible value from the original data.
#
# 2. Label/Ordinal encoding
# * It refers to converting the labels to numeric form so as to convert them into a machine readable format.
# * ML algoritms will decide in a  better way how those labels must be operated.
# * it is an important preprocessing step for the structured dataset in supervised learning
# * it is the simplest way to encode features for a ML algoritm.
# * In thsi method, the categorical data is converted intonnumerical data
# * Each category is assigned a numerical value

# %% [markdown]
# Scaling
#
# * In ML, scaling is a technique that transforms data so that features have a common scale. This allows models to train more effectively.
#
# How it works?
# * Normalization can change the range of values in a dataset.
# * It can also transform values to a common scale like 0 to 1
# * It can be applied to a singel column or multiple columns in a dataset.
#
# 1. Min-Max Scaling(Normalization)
# * It is a scaling technique in which the values are shifted and rescaled so that they end up ranging between 0 and 1.
# * Formula:
#                 X'=(X - Xmin)/(Xmax-Xmin)
#
# price                        scaled version
#                                     min-max scaling
#
#        4000                        (4000-2000)/(4000-2000) = 1
#
#        2000                        (2000-2000)/(4000-2000) = 0
#
#        3000                        (3000-2000)/(4000-2000) = 1.5
#
#        2000                        (2000-2000)/(4000-2000) = 0
#
#
# 2. Standardization(Z-Score Normalization)
#
#              Z = (X - µ)/σ
# * Centers data around zero with a unit variance
# * Less sensitive to outliers compared to min max scaling.
# * Commonly used in algorithms like SVM , logistic regression , and k-means.
#
#       price                         z-score
#
#        4000                        (4000-2500)/(224) = 6.69
#
#        2000                        (2000-2500)/(224) = -8.92
#
#        3000                        (3000-2500)/(224) = 4.46
#
#        1000                        (1000-2500)/(224) = -13.39
#
#        2000                         (2000-2500)/(224) = -8.92
#
#                                        mean=2500
#                                        standard deviation=224

# %% [markdown]
# ML Workflow
#
# 1. Problem Definition
# 2. Data Collection
# 3. Data preprocessing and cleaning(encoding,DAV)
# 4. Exploratory data analysis(DAV)
# 5. Feature engineering & selection: It is the process of selecting the input features for creating the ml model.
# 6. Split the dataset into input features and target column
# 7. Scaling the input feature data
# 8. Divide into train dataset and test dataset
# 9. Apply the ML algo into training data
# 10. Model evaluation
# 11. Deployment

# %% [markdown]
# Train Test Split data
#
# ![Screenshot (146).png](data:image/png;base64,...)

# %% [markdown]
# Two Fundamental Types Of Supervised Learning Problems
#
# 1. Regression problems
# * Regression is used when the target variable (output) is continuous.
# * it predicts numerical values
#
# * examples of regression problems:
#
#
#  Predicting house prices based on features like size, location and number of bedrooms.
#
#  estimating the salary of an employee given their experience and education
#
#  forecasting the stock market prices
#
#  predicting the temp based on historical weather data.
#
#  * Common regression algorithms
#
#  Linear regression(Simple and multiple)
#
#  Polynomial regression
#
#  Decision tree regression
#
#  Random forest regression
#
#  Support vector regression
#
#  * Evaluation Metrics for regression
#
#  Mean absolute error(MAE)
#
#  Mean Squared Error (MSE) & Root mean squared error(RMSE)
#
#  R 2 score(Coefficient of determination)

# %% [markdown]
# 1. Mean Absolute error(MAE)
#
# * it is a measure of the average of the absolute difference between each actual value and predicted value.
# * formula
# MAE = (1/n) * Σ |y_i - ^y_i|
#
# Where:
#
# MAE: is the Mean Absolute Error
#
# n: is the number of data points
#
# y_i: is the actual value of the i-th data point
#
# ^y_i: is the predicted value of the i-th data point
#
# | | represents the absolute value (taking the positive value of the difference)
#
# Σ: represents the sum over all data points
#
#
# Employees                Actual                 Predicted
#
#     person_1             $3000                  $3800
#
#     person_2             $4400                  $4600
#
#     person_3             $2500                  $2300
#
#     person_4             $3000                  $3400
#
#     person_5             $4000                  $4120
#
# |3000-3800|=800
#
# |4400-4600|=200
#
# |2500-2300|=200
#
# |3000-3400|=400
#
# |4000-4120|=120
#
# Average of the summed up error(800 + 200 + 200 + 400 + 120)/5= 344

# %% [markdown]
# MEAN SQUARED ERROR(MSE)
#
# *Takes the average of the square of the difference between the original values and the predicted values
#
# *As we take square of the error, the effect of larger errors(sometimes outliers) become more pronounced than smaller error
#
# *Before applying MSE,we must eliminate all nulls/infinites from the input
#
# *formula
#
#         MSE =  (1/n) * Σ(yi - ŷi)²
# Where:
#
# n: is the total number of observations.
#
# yi: is the actual value of the target variable for observation i.
#
# ŷi: is the predicted value for observation i.
#
# Σ: represents the sum of all squared differences.
#
#       Employees            Actual               Predicted
#
#       person_1             $3000                  $3800
#
#       person_2             $4400                  $4600
#
#       person_3             $2500                  $2300
#
#       person_4             $3000                  $3400
#
#       person_5             $4000                  $4120
# (3000-3800)^2 = 640000
#
# (4400-4600)^2 = 40000
#
# (2500-2300)^2 = 40000
#
# (3000-3400)^2 = 160000
#
# (4000-4120)^2 = 14400
#
# The average of the squared error summations is : (640000+40000+40000+160000+14400)/5 = 178880

# %% [markdown]
# R squared(r^2)
#
# * the r^2 score(pronounced r square) is a stastical measure used to evaluate the performance of regression models in ML.
#
# * It indicates how well the models predictions approximate the actual data points.
#
# * r^2 or the coefficent of determination
#
# ![Screenshot (148).png](data:image/png;base64,...)

# %% [markdown]
# R2 score=1-((((3000-3800)^2 + (4400-4600)^2 + (2500-2300)^2))/((3000-3000)^2 + (4400-3000)^2 + (2500-3000)^2))
#
# considered only 3 instances

# %% [markdown]
# 2. Classification Problems
#
# * classification is used when the target variable is categorical. It predicts labels or classes.
#
# Examples:
# - email spam detection(spam or not spam)
# - disease prediction(healthy or diseased)
# - handwritten digit recognition(0-9)
# - sentiment analysis(positive,negative,neutral)
#
# Evaluation metrics for classification
# - accuracy
# -precision, recall , f1 score
# - ROC - AUC score(for binary classification)
# - confusion matrix

# %% [markdown]
# Confusion matrix
#
# * it takes the classification results and groups them into four categories:
#
# True positive(TP): when both the actual and predicted values are 1.
#
# True negative(TN): when both the actual and predicted values are 0.
#
# False positive(FP): when  the actual value is 0 and predicted value is 1.
#
# False negative(FN): when  the actual value is 1 and predicted value is 0.

# %% [markdown]
# Accuracy
#
# Accuracy in classification problems is the number of correct predictions made by the model over all kinds predictions made.
#
# Accuracy=no of correct predictions/ total no of predictions
#
#
# Accuracy = (True Positives + True Negatives) / (True Positives + True Negatives + False Positives + False Negatives).
#
#
# Here's a breakdown of the terms:
#
# True Positives (TP): The model correctly predicted positive cases.
#
# True Negatives (TN): The model correctly predicted negative cases.
#
# False Positives (FP): The model incorrectly predicted positive cases (also known as a Type I error).
#
# False Negatives (FN): The model incorrectly predicted negative cases (also known as a Type II error).

# %% [markdown]
# 1. Precision
#
# Definition: Out of all the times the model said “yes” (positive), how many times was it correct?
#
# Formula:
# Precision = True Positives / (True Positives + False Positives)
#
# Example:
# Suppose a model identifies 10 emails as spam, but only 7 are actually spam.
#
# True Positives (TP) = 7
#
# False Positives (FP) = 3
#
# Precision = 7 / (7 + 3) = 0.7 or 70%
# Meaning: 70% of the time when it said “spam,” it was right.
#
# 2. Recall
#
# Definition: Out of all the actual “yes” (positive) cases, how many did the model find?
#
# Formula:
# Recall = True Positives / (True Positives + False Negatives)
#
# Example:
# There are 10 actual spam emails, and the model correctly identified 7 of them.
#
# True Positives (TP) = 7
#
# False Negatives (FN) = 3 (missed spam)
#
# Recall = 7 / (7 + 3) = 0.7 or 70%
# Meaning: The model found 70% of the real spam.
#
# 3. F1 Score
#
# Definition: A balance between precision and recall. It's the harmonic mean of both.
#
# Formula:
# F1 Score = 2 × (Precision × Recall) / (Precision + Recall)
#
# Example:
# If Precision = 0.7 and Recall = 0.7
#
# F1 Score = 2 × (0.7 × 0.7) / (0.7 + 0.7) = 0.7
# Meaning: Overall balance between being accurate and catching all spam is 70%.

# %% [markdown]
# **Linear Regression**
#
# * It is a fundamental supervised learning algorithm used for predicting continuous values based on one or more input features.
# * It establishes a linear relationship between the independent variables (X) and the dependent variable(Y)
#
# Formula:
# Y = b0 + b1X1 + b2X2 + ... + epsilon,
#
# where Y is the dependent variable, b0 is the y-intercept, b1, b2, ..., bn are the regression coefficients, and X1, X2, ..., Xn are the independent variables. This formula predicts the value of Y based on the values of the independent variables and their coefficients.
#
# ![Screenshot (149).png](data:image/png;base64,...)

# %% [markdown]
# Example for linaer regression
#
# X1_                               X2_    Y
# 5                                 20     70
# 5                                 4      22
# 4                                 6
#
# Y=2X1+3X2

# %% [markdown]
# Assumptions of linear regression
#
# To get reliable results linear regression assumes:
# * Linearity- The realtionship between X and Y is linear.
# * Independence- The observations are independent of each other
# * Homoscedasticity: Constant variance of residuals
# * No Multicollinearity: Independent variables should not be highly correlated.

# %% [markdown]
# Logistic Regression
# * It is a ML algorithm used for classification(mainly binary classification)
# * It predicts whether something belongs to one category or another(ex:spam or not spam , disease or not disease)
# * instead of predicting the actual values(like linear regression ) it predicts the probabilities.
# * it uses a special function called the sigmoid function(logistic function).

# %% [markdown]
# * in case of sigmoid function makes z as 'y' variable.
#
# σ(x) = 1/(1 + e−x).(instead of x take as 'y')
# * this gives u the probaabilty of class 1
#
# * this function squeezes any value into a range between 0 and 1.
# 1. if the result is closer to 1, we classify it as one category(ex:'yes')
# 2.if the result is closer to 0, we classify it as other category(ex:'no')
# * to get the probability of class 0
#
# P(y=0|x)=1-P(y=1|x)

# %% [markdown]
# Decision Boundary
# * LOgistic regression makes decisions based on probabilities:
# 1. if the probability is>=0.5, it predicts 1(yes,positive,true etc)
# 2. if the probability is<=0.5, it predicts 0(no,negative,false etc)
#
# Here's the plotted curve of the **sigmoid function**. As you can see:
#
# * The curve smoothly transitions from 0 to 1.
# * The midpoint (where $x = 0$) maps to 0.5.
# * The function asymptotically approaches 0 as $x \to -\infty$ and 1 as $x \to +\infty$.
#
#
#
#
# picture
#
# The Hypothesis(Prediction formula)![sigmoid_curve.svg](data:image/svg+xml;base64,...)
# * logistic regression makes prediction using the formula:
#
# h0(x)=1/(1+e^-(b0+b1x1+b2x2+........+bnxn)
#
# here b is beta-
# * b0,b1,b2,.... are weights(parameters) that the model learns).
# * x1,x2,.... are the input features(ex:age,height,salary)
#
#
#
# Multi class logistic regression
# * if there are more than 2 categories (ex:dog,cat,rabbit), we use softmax regression instead of the basic logistic regression.
#
# * the softmax function assigns probabilities to all classes and picks the most likely one.
#
# The **Softmax function** is a mathematical function often used in machine learning, especially in classification problems. It converts a vector of raw scores (logits) into probabilities that sum up to 1. This makes it useful for multiclass classification tasks, where each class is assigned a probability.
#
# ---
#
# ### **Softmax Function Formula:**
#
# For a vector $z = [z_1, z_2, \dots, z_n]$, the softmax function $\sigma(z)_i$ for the $i^{th}$ element is:
#
# $$
# \sigma(z)_i = \frac{e^{z_i}}{\sum_{j=1}^{n} e^{z_j}}
# $$
#
# ---
#
# ### **Example:**
#
# Let's say you have raw scores (logits) from a model for 3 classes:
#
# $$
# z = [2.0, 1.0, 0.1]
# $$
#
# #### **Step-by-step Calculation:**
#
# 1. **Exponentiate each element**:
#
#    $$
#    e^{2.0} = 7.389,\quad e^{1.0} = 2.718,\quad e^{0.1} = 1.105
#    $$
#
# 2. **Sum of exponentials**:
#
#    $$
#    7.389 + 2.718 + 1.105 = 11.212
#    $$
#
# 3. **Divide each exponential by the sum**:
#
#    $$
#    \text{Softmax}(z) = \left[\frac{7.389}{11.212}, \frac{2.718}{11.212}, \frac{1.105}{11.212}\right]
#    $$
#
# 4. **Final probabilities**:
#
#    $$
#    \text{Softmax}(z) \approx [0.659, 0.242, 0.099]
#    $$
#
# ---
#
# ### **Interpretation:**
#
# * The model assigns the highest probability (≈ 65.9%) to the first class.
# * All probabilities add up to 1:
#
#   $$
#   0.659 + 0.242 + 0.099 \approx 1.0
#   $$
#
# ---
#
# Use Case in Machine Learning:
#
# In neural networks, the softmax function is typically used in the **output layer** of a model that performs **multiclass classification**. It helps the model to express confidence levels for each possible class.

# %% [markdown]
# Advantages
# * simple and easy to implement
# * works well for binary classification
# * fast and efficient
# * provides probability scores
#
# Disadvantages
# * Assumes a linear relationship between features and the outcome.
# * Not great for complex,non linear data
# * sensitive to outliers

# %% [markdown]
# 23/05/2025
# K nearest neighbours(KNN)
#
# * It is a supervised ML algorithm that can be used to solve both classification and regression tasks.
#
# KNN Formula (Euclidean Distance)
# he most commonly used formula in KNN is the Euclidean distance between two points
# 𝑋
# =
# (
# 𝑥
# 1
# ,
# 𝑥
# 2
# ,
# .
# .
# .
# ,
# 𝑥
# 𝑛
# )
# X=(x
# 1
# ​
#  ,x
# 2
# ​
#  ,...,x
# n
# ​
#  ) and
# 𝑌
# =
# (
# 𝑦
# 1
# ,
# 𝑦
# 2
# ,
# .
# .
# .
# ,
# 𝑦
# 𝑛
# )
# Y=(y
# 1
# ​
#  ,y
# 2
# ​
#  ,...,y
# n
# ​
#  ):
#
#  Distance(X,Y)=
# (x
# 1
# ​
#  −y
# 1
# ​
#  )
# 2
#  +(x
# 2
# ​
#  −y
# 2
# ​
#  )
# 2
#  +⋯+(x
# n
# ​
#  −y
# n
# ​
#  )
# 2
#
# Or, more generally:
#
# Distance
# (
# 𝑋
# ,
# 𝑌
# )
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑥
# 𝑖
# −
# 𝑦
# 𝑖
# )
# 2
# Distance(X,Y)=
# i=1
# ∑
# n
# ​
#  (x
# i
# ​
#  −y
# i
# ​
#  )
# 2
#
# ​

# %% [markdown]
# Characteristics of KNN
#
# * It is of the simplest algorithms.
# * It assumes the similarity between the new case /data and available cases and put the new case into the category that is most similar to the available categories.
# * It stores all the  available data and classifies a new data point based on similarity.This means that when the new data appears then it can be easily classified into a well suite category by using KNN algorithm.
# * The K-Nearest Neighbors (KNN) algorithm is a non-parametric algorithm, which means it doesnot take any assumption on underlying data.
# * It is also called an lazy learner algorithm bcoz it doesnot learn from the training set immediately instead it stores the dataset and at the time of classification it performs the action on dataset
# * KNN at the training phase just stores the dataset and when it gets the newdata it classifies the data into a category that is much similar to new dataset.

# %% [markdown]
# How does KNN work?
# STEPS
# 1. Select the number K of  the neighbors
# 2. Calculate the eucleadian distance of K number of neighbors
# 3. Take the K nearest neighbors as per the calculated eucledian distance
# 4. Among these k neighbors count the number of data points in each category.
# 5. assign the new data points to that category for which number og neighbor is maximum
# 6. our model is ready.

# %% [markdown]
# Suppose the new data point and we need to put in the required category. Consider the below image

# %% [markdown]
# ![Screenshot (151).png](data:image/png;base64,...)

# %% [markdown]
# * first we will choose the number of neighbors so we will choose k=5
# * Next we will calculate the euclidean distance between the data points.
# * By calculating the euclidean dist we came to know the nearest neighbors, as the 3 nearest neighbors in category A and 2 nearest neighbors in category  B
# * As we see 3 nearest neighbors in category A, hence the new data point belongs to category A.

# %% [markdown]
# How to select the value of K in KNN algoritm?
# * There is no particuler way to choose the k value.The most preffered value is 5.
# * A very low value for K such as k=1 or K=2 can be noisy and lead to the effects of outliers in the model.
# * Large values for K are good,but it may find some difficulties.

# %% [markdown]
# Advantages of KNN and DIsadvantages of KNN
# Advantages
# * it is simple to implement
# * It is robust to the noisy training data
# * it can be more effective if the training data is large
#
# Disadvantages
# * Always need to determine the value of k which may be complex some time.
# * The computation cost is high because of calculating the dist b/w the data points for all the training samples.

# %% [markdown]
# Naive Bayes Algorithm
#
# * It is supervised learning algorithm, it's a probabilistic classifier based on Baye's theorem that is used for classification tasks.
# * It's called "naive" because it assumes that features are independent of each other which is rarely true in practice but it still performs well.
#
# Formula:
# P(C|X)=(P(X|C)*P(C) )
#       ------------
#          P(X)
#
# WHERE:
# P(C|X):Posterior probability of class C given the features X
# P(X|C):Likelihood of observing features X given class C
# P(C):Prior probability of class C
#  P(X):Probability of features X

# %% [markdown]
# Working of naive bayes classification
#
# 1.  Train the model using labelled data
#    You start with a dataset like this:
#      Email text  ---------------                      Label
#
#      "Buy now free offer"--------------Spam
#
#      "Meeting schedule"-----------------Not spam
#
#      "Free Coupons today"----------------Spam
#
#      "project-update---------------------Not spam
#
#      * After this you have to separate the data into features (the words) and labels(spam/not spam)
#
#   2. Calculate Probabilities
#    a. Prior Probability P(C)
#               P(Spam)=Number of Spam emails/Total number of emails
#
#               p(spam)=2/4=0.5
#
#               P(Notspam)=2/4=0.5
#
#   b. Likelihood
#   * P(word|class)-You have to count the how often each word appears in spam and not spam emails.
#   -Example:
#   * Word"free" appears 2 times in spam emails.
#   * Word"free" appears 0 times in notspam emails.
#
#   P("free|Spam)=2/Total words in spam emails
#
#   P("free|NotSpam)=0/Total words in notspam emails
#
#   3. Use Bayes theorem to compute posterior
#   Now suppose a new email says:"Free offer today"
#   * we compute the probability of each class:
#
# pi equation
#
#   P(Spam|"Free offer today") directly proportional P(Spam).P("free"|spam)*P("offer"|spam)*P("today"|spam)
#
#   do same for not spam
#
#
#   4.Assign the class with highest posterior
#   * Whichever class has the higher total probability that's the class we assign to the email.
#
#   so if:
#   * P(Spam|email)=0.0004
#   * P(NotSpam|email)=0.0001
#
#   * we classify it as spam

# %% [markdown]
# Decision tree algo
#
# * Hyper parameter tuning(Hyperparameter tuning (or hyperparameter optimization) is the process of choosing the best set of hyperparameters for a machine learning model to improve its performance.)
#
#
# * it is a classification problem so we have imported DecisionTreeClassifier() otherwise we would have imported DecisionTreeRegressor()in case of regression

# %% [markdown]
# May  27 notes copy

# %% [markdown]
# Random Forest Algorithm
#
# Random Forest is a supervised machine learning algorithm which is based on ensemble learning. In this project, two Random Forest Classifier models to predict the safety of the car, one with 10 decision-trees and another one with 100 decision-trees. The expected accuracy increases with number of decision trees in the model
#
# Introduction to Random Forest algorithm
#
#
#
# Random forest is a supervised learning algorithm. It has two variations one is used for classification problems and other is used for regression problems. It is one of the most flexible and easy to use algorithm. It creates decision trees on the given data samples, gets prediction from each tree and selects the best solution by means of voting. It is also a pretty good indicator of feature importance.
#
# Random forest algorithm combines multiple decision trees, resulting in a forest of trees, hence the name Random Forest. In the random forest classifier, the higher the number of trees in the forest results in higher accuracy.
#
# ![Screenshot (162).png](data:image/png;base64,...)

# %% [markdown]
# Random Forest algorithm intuition
#
# Raedom forest algorithm intuition can be divided into two stages
#
# In the first stage, we randomly select "k" features out of total features and build the random forest. In the first stage, we proceed as follows
#
# 1. Randomly select features from a total of features where   k<m
#
# 2. Among the  k features, calculate the node  d using the best split point
#
# 3. Split the node into daughter nodes using the best split
#
# 4. Repeat 1 to 3 steps until 1 number of nodes has been reached
#
# 5. Build forest by reperating steps 1 to 4 for n number of times to create n number isf trees
#
# Is the second stage, we make predictions using the trained random forest algorithm
#
# 1. We take the test features and use the rules of each randomly created decision tree to predict the outcome and stores the predicted outcome
#
# 2. Then, we calculate the votes for each predicted target.
#
# 3. Finally we consider the high voted predicted target as the final prediction from the random forest algorithm.

# %% [markdown]
# 3. Advantages and disadvantages of random forest algorithm
#
# The advantages of Random forest algorithm are:
# 1. It can be used to solve both classification and regression problems.
#
# 2.  It is considered as very accurate and robust(immune to errors) model because it uses large number of decision-trees to make predictions.
#
# 3. Random forests takes the average of all the predictions made by the decision trees, which cancels out the biases. So, it does not suffer from the overfitting problem.
#
# 4. Random forest classifier can handle the missing values. There are two ways to handle the missing values. First is to use median values to replace continuous variables and second is to compute the proximity-weighted average of missing values.
#
# Disadvantages of Random Forest algorithm are listed below:
#
# 1. The biggest disadvantage of random forests is its computational complexity. Random forests is very slow in making predictions because large number of decision trees are used to make predictions. All the trees in the forest have to make a prediction for the same input and then perform voting on it. So it is a time consuming process.

# %% [markdown]
# Feature selection with Random Forests
#
# Random forest algorithms can be used for feature selection process.This algorithm can be used to rank the importance of variables in a regression or classification problem.
#
# We measure the variable importance in a dataset by fitting the random forest algorithm to the data.
#
#  The importance of the j-th feature was measured after training. The values of the j-th feature were permuted among the training data and the out-of-bag error was again computed on this perturbed dataset(meaning a dataset that has been intentionally modified). The importance score for the j'th feature is compute by averaging the difference in out-of-bag error before and after the permutation over all trees. The score is normalized by the standard deviation of these differences.
#
#  Features which produce large values for this score are ranked as more important than features which produce small values.Based on this score, we will choose the most important features and drop the least important ones for model building.

# %% [markdown]
# Introduction to Clustering
#
# * Clustering is a type of unsupervised learning where the goal is to group similar data points together based on their features.
# * No labeled data is used.
# * The algorithm tries to discover the inherent structure in the data.
# * Common applications : Customer segementation,Social network analysis,image compression etc
# ![WhatsApp Image 2025-06-02 at 2.56.58 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Types of Clustering
# 1. Partitioning Methods(ex:K-means)
# 2. Hierarchial clustering
# 3. Density Based Methods(ex:DBSCAN)
# 4. Model Based Methods

# %% [markdown]
# K Means Clustering
#
# * K Means is one of the most popular and simplest clustering algorithms.
# * Goal:Partition the dataset into K clusters,where each data point belongs to the cluster with the nearest mean.
# * Algorithm steps:
# 1. Choose the number of clusters K.
# 2. Randomly intialise K centroids.
# 3. Assign each point to the nearest centroid.
# 4. Recalculate centroids as the mean of the assigned points.
# 5. Repeat steps 3 and 4 until convergence(until there is no change in centroids).
# ![WhatsApp Image 2025-06-02 at 3.05.07 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# K-Means algorithm:Expectation-Maximization
#
# * Expectation-Maximization(E-M)is a powerful algorithm that comes up in a variety of contexts within data science. kmeans is a particularly simple and easy-to-understand application of the algorithm.
#
# In short, the expectation-maximization approach here consists of the following procedure:
#
#
# 1. Guess some cluster centers
#
# 2. Repeat until converged
#
#    * E-Step assign points to the nearest cluster center
#
#   *  M-Step set the cluster centers to the mean
#
# Here the "E-step" or "Expectation step" is so-named because it involves updating our expectation of which cluster each point belongs to.
#
# The "M-step" or "Maximization step" is so-named because it involves maximizing some fitness function that defines the location of the cluster centers - in this case, that maximization is accomplished by taking a simple mean of the data in each cluster.
#
# The literature about this algorithm is vast but can be summarized as follows:under typical circumstances, each repetition of the E-step and M-step will always result in a better estimate of the cluster characteristics.

# %% [markdown]
# figure neeed to be added (for large data)
#
# ![WhatsApp Image 2025-06-02 at 3.34.56 PM.jpeg](data:image/jpeg;base64,...)
#
#
#
#
#
# * With every pass of the algorithm,each point is assigned to its nearest cluster center.

# %% [markdown]
# Advantages:
# 1. Simple and fast
# 2. Works well with large datasets.
#
# Disadvantages:
# 1. Need to pre-specify K.
# 2. Sensitive to initialization and outliers.
# 3. Assumes clusters are spherical and equally sized.

# %% [markdown]
# Elbow Method
# * Used to determine the optimal number of clusters(K) in K means.
# * Steps:
# 1. Run K-Means for a range of K values(ex:1 to 10).
# 2. For each K,compute the within cluster sum of squares(WCSS) - also known as inertia.
# 3. Plot K vs WCSS
# 4. Look for an 'elbow' in the plot - the point where the rate of decrease sharply slows.
#
#
#
#
# figure
# ![Screenshot (164).png](data:image/png;base64,...)
#
#
#
#
#
#
# * 'WCSS' which stands for within Cluster  sum of squares.
# * it is a measure of variability in each cluster.
# * the goal is to minimize this value when choosing the number of clusters.

# %% [markdown]
# K means inertia(WCSS)
#
# * In K-Means clustering, "inertia" refers to the sum of squared distances between each data point and its assigned cluster centroid.
#
# * It measures how tightly the data points are clustered around the centroids.
#
# * A lower inertia value indicates that the clusters are denser and more compact, meaning the points are closer to their respective centroids.
